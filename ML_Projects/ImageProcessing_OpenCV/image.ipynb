# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("cap.jpg")
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=527x1000 at 0x251B0E227C0>

# %%
arr = np.array(pil)
arr.shape
#(rows,columns,depth)
# Out:
# (1000, 527, 3)

# %%
cut = arr[10:550, 50:520 ]
plt.imshow(cut)

# %%
cut = arr[:,:,0]
plt.imshow(cut)
